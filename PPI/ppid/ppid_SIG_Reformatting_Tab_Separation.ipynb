# %%
import pandas as pd
import numpy as np

# %%
sig = pd.read_table("ppid.sig", header = None, sep = ' ')
sig.drop([1, 2, 3,4, 6, 7, 8, 9, 10, 11, 12], axis =1 , inplace = True)
sig.head()
# Out:
#         0        5
# 0   SCN3A     LRP1
# 1  PPP2CA     ETF1
# 2    TRHR      LTF
# 3  GNB2L1   GABRA1
# 4    GRB2  RAPGEF1

# %%
#Insert first four columns for .sig file format (NaNs)
sig.insert(1, 'NA-1', str(np.nan))
sig.insert(2, 'NA-2', str(np.nan))
sig.insert(3, 'NA-3', str(np.nan))
sig.insert(4, 'NA-4', str(np.nan))

#Insert next four columns for .sig file format (NaNs)
sig.insert(6, 'NA-5', str(np.nan))
sig.insert(7, 'NA-6', str(np.nan))
sig.insert(8, 'NA-7', str(np.nan))
sig.insert(9, 'NA-8', str(np.nan))

sig.insert(10, 'Sign', str(np.nan))

sig.insert(11, 'Interaction', str(np.nan))

sig.insert(12, 'PubMed', str(np.nan))

#View dataframe
sig.head()
# Out:
#         0 NA-1 NA-2 NA-3 NA-4        5 NA-5 NA-6 NA-7 NA-8 Sign Interaction  \
# 0   SCN3A  nan  nan  nan  nan     LRP1  nan  nan  nan  nan  nan         nan
# 1  PPP2CA  nan  nan  nan  nan     ETF1  nan  nan  nan  nan  nan         nan
# 2    TRHR  nan  nan  nan  nan      LTF  nan  nan  nan  nan  nan         nan
# 3  GNB2L1  nan  nan  nan  nan   GABRA1  nan  nan  nan  nan  nan         nan
# 4    GRB2  nan  nan  nan  nan  RAPGEF1  nan  nan  nan  nan  nan         nan
#
#   PubMed
# 0    nan
# 1    nan
# 2    nan
# 3    nan
# 4    nan

# %%
#Create dictionary 'sigd' with index numbers as keys
sigd = dict([(key, '') for key in sig.index])

# loop through rows with iterrows()
for index, rowData in sig.iterrows():
    line = ('\t'.join(rowData))
    sigd[index] = line
    
#Transfer tab-separated info into a new txt file
#Make sure to include in ReadMe corresponding column names
with open('ppid.sig', 'w') as openfile:
    for index in sigd:
        openfile.write(str(sigd[index]) + '\n')
